# %%
# !pip install langchain
# !pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import os

# %%
from google.colab import userdata
oi = userdata.get('open1')

# %%
os.environ['OPEN_AI_KEY'] = oi

# %%
import langchain

from langchain_openai import OpenAI,ChatOpenAI

# %%
model = OpenAI(model="gpt-5.2-2025-12-11",)

# %%
model.invoke("who won the 3rd ind vs southafrica who is win ")

# %%
cm = ChatOpenAI(model="gpt-5.2-2025-12-11",)

# %%
response = cm.invoke("who won the 3rd ind vs southafrica who is win ")

# %%
response.content

# %%
cm = ChatOpenAI(model ="gpt-4.1-2025-04-14",max_tokens=3)

# %%
response = cm.invoke([("system','you act like one year old"),("user","tell me about india")])

# %%
response.content

# %%
### gpt-3.5-turbo-instruct----regular model

# %%
model = OpenAI(model='gpt-3.5-turbo-instruct',max_tokens=20)

# %%
model.incove("tell me about india")
