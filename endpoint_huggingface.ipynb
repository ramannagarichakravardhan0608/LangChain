# %%
# !pip install langchain
# !pip install langchain_huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.1/476.1 kB 23.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.1.3
#     Uninstalling langchain-core-1.1.3:
#       Successfully uninstalled langchain-core-1.1.3
# ...

# %%
import os

# %%
from google.colab import userdata
hf = userdata.get('hg')

# %%
os.environ["HF_TOKEN"] = hf

# %%
import langchain

# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace

# %% [markdown]
# deepseek

# %%
model = HuggingFaceEndpoint(repo_id="deepseek-ai/DeepSeek-V3.2",temperature=0.5)

# %%
cm = ChatHuggingFace(llm=model)

# %%
response = cm.invoke("tell me about the rohit sharma")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
response.content
# Out:
# 'Of course! Rohit Sharma is one of the most celebrated and successful cricketers in the modern era, particularly renowned for his elegant batting and captaincy. Here’s a detailed look at his career and legacy:\n\n### **Nicknames**\nHe is affectionately called **"Hitman"** for his big-hitting ability and **"The Captain"** of modern Indian cricket. Another popular one is **"Sharma Ji Ka Beta"** (Mr. Sharma\'s son), a humorous Indian pop-culture reference to the ideal, successful son.\n\n### **Playing Style & Strengths**\n*   **Elegant & Lazy Grace:** His batting is often described as effortlessly elegant. He has extra time to play his shots, making even the most aggressive batting look calm and composed.\n*   **Master of Pull & Hook Shots:** These are his signature bread-and-butter shots, played with remarkable control and power.\n*   **Supreme Timing:** He relies more on exquisite timing than brute force, which allows him to clear boundaries with seemingly minimal effort.\n*   **Recor
# ...

# %% [markdown]
# llama

# %%
model1 = HuggingFaceEndpoint(repo_id="meta-llama/Llama-3.1-8B-Instruct",temperature=0.8)

# %%
llama = ChatHuggingFace(llm = model1)

# %%
llama.invoke("tell me about rohit sharma")
# Out:
# AIMessage(content="Rohit Sharma is an Indian international cricketer who plays for the Indian national team. He is a right-handed batsman and a part-time offbreak bowler. Born on April 30, 1987, in Banswada, Telangana, India, Sharma has become one of the most successful and dominant batsmen in international cricket.\n\n**Early Life and Career:**\n\nRohit Sharma began his cricketing journey at the age of 8 in his village. He was coached by his father, a former cricket player, who recognized his son's potential at a young age. Sharma's talent was soon noticed by the Mumbai Cricket Association, and he joined the MCA's junior cricket academy.\n\n**International Debut:**\n\nSharma made his international debut in 2007, playing for India in a one-day international (ODI) match against Sri Lanka. However, he struggled to establish himself in the team, and it wasn't until 2011 that he became a regular member of the Indian ODI team.\n\n**Breakthrough and Success:**\n\nSharma's breakthrough came
# ...

# %%
model2 = HuggingFaceEndpoint(repo_id="google/gemma-3-27b-it",temperature=0.5)

# %%
gamma = ChatHuggingFace(llm=model2)

# %%
gamma.invoke("who is ramannagari chakravardhan")
# Out:
# AIMessage(content="Ramannagari Chakravardhan (often simply called Chakravardhan) is a highly respected and influential figure in the Telugu literary world, particularly known for his contributions to **modern Telugu poetry**. Here's a breakdown of who he is:\n\n*   **Poet and Literary Critic:** He's primarily a poet, but also a significant literary critic. His poetry is characterized by its philosophical depth, exploration of existential themes, and innovative use of language.\n*   **Style & Themes:** Chakravardhan's poetry often delves into themes of alienation, the human condition, the search for meaning, and the complexities of modern life. He's known for a style that blends traditional Telugu poetic forms with modern sensibilities. He's considered a major voice in *Navya* (modern) Telugu poetry.\n*   **Awards & Recognition:** He has received numerous awards for his literary work, including:\n    *   Sahitya Akademi Award (2011) for his poetry collection *Mrutyunjaya*.\n    *   Ce
# ...
