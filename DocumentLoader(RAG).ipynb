# %%
# !pip install langchain_community
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import langchain_community
from langchain_community.document_loaders import  TextLoader
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
# text loader this convert any txt or .md extract the text from that

# %%
do = TextLoader(file_path="/content/chakravardhan.docx.txt") #document object

# %%
do #support two method --load is used to load the data from the documnet object as a list of values

# %%
len(do.load())
# Out:
# 1

# %%
do.load()[0].metadata
# Out:
# {'source': '/content/chakravardhan.docx.txt'}

# %%
do.load()[0].page_content
# Out:
# '\ufeffCLUSTERED FOREST FIRE PREDICTION USING DEEP LEARNING WITH EFFECTIVE SCALING AND THRESHOLD BASED FEATURE SELECTION\nA PROJECT REPORT\nSubmitted by\nRAMANNAGARI CHAKRAVARDHAN [RA2111003010767]\n       PERVATHANENI LIKITH CHOWDARY [RA2111003010789]\nUnder the Guidance of\nDr. M. SENTHIL RAJA\nAssistant Professor, Department of Computing Technologies\n\n\nin partial fulfillment of the requirements for the degree of\n\n\nBACHELOR OF TECHNOLOGY\nin\nCOMPUTER SCIENCE AND ENGINEERING\n\n\n\n\n Logo, company name  Description automatically generated \n\n\n\nDEPARTMENT OF COMPUTING TECHNOLOGIES COLLEGE OF ENGINEERING AND TECHNOLOGY SRM INSTITUTE OF SCIENCE AND TECHNOLOGY KATTANKULATHUR– 603 203\nMAY 2025\n Logo \n\n\n\nSRM INSTITUTE OF SCIENCE AND TECHNOLOGY KATTANKULATHUR–603 203\nBONAFIDE CERTIFICATE\n\n\nCertified that 18CSP109L / I8CSP111L project report titled “CLUSTERED FOREST FIRE PREDICTION USING DEEPLEARNING WITH EFFECTIVE THRESHOLD BASED FEATURE SELECTION” is the Bonafide work
# ...

# %%
do1 = TextLoader(file_path="/content/markdown-sample.md")

# %%
do1.load()[0].page_content
# Out:
# 'An h1 header\n============\n\nParagraphs are separated by a blank line.\n\n2nd paragraph. *Italic*, **bold**, and `monospace`. Itemized lists\nlook like:\n\n  * this one\n  * that one\n  * the other one\n\nNote that --- not considering the asterisk --- the actual text\ncontent starts at 4-columns in.\n\n> Block quotes are\n> written like so.\n>\n> They can span multiple paragraphs,\n> if you like.\n\nUse 3 dashes for an em-dash. Use 2 dashes for ranges (ex., "it\'s all\nin chapters 12--14"). Three dots ... will be converted to an ellipsis.\nUnicode is supported. ☺\n\n\n\nAn h2 header\n------------\n\nHere\'s a numbered list:\n\n 1. first item\n 2. second item\n 3. third item\n\nNote again how the actual text starts at 4 columns in (4 characters\nfrom the left side). Here\'s a code sample:\n\n    # Let me re-iterate ...\n    for i in 1 .. 10 { do-something(i) }\n\nAs you probably guessed, indented 4 spaces. By the way, instead of\nindenting the block, you can use delimited blocks, if
# ...

# %%
# !pip install "unstructured[all-docs]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 40.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 39.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# %%
uo = UnstructuredMarkdownLoader(file_path="/content/markdown-sample.md",mode='single')

# %%
uo.load()
# Out:
# [Document(metadata={'source': '/content/markdown-sample.md'}, page_content='An h1 header\n\nParagraphs are separated by a blank line.\n\n2nd paragraph. Italic, bold, and monospace. Itemized lists look like:\n\nthis one\n\nthat one\n\nthe other one\n\nNote that --- not considering the asterisk --- the actual text content starts at 4-columns in.\n\nBlock quotes are written like so.\n\nThey can span multiple paragraphs, if you like.\n\nUse 3 dashes for an em-dash. Use 2 dashes for ranges (ex., "it\'s all in chapters 12--14"). Three dots ... will be converted to an ellipsis. Unicode is supported. ☺\n\nAn h2 header\n\nHere\'s a numbered list:\n\nfirst item\n\nsecond item\n\nthird item\n\nNote again how the actual text starts at 4 columns in (4 characters from the left side). Here\'s a code sample:\n\n# Let me re-iterate ...\nfor i in 1 .. 10 { do-something(i) }\n\nAs you probably guessed, indented 4 spaces. By the way, instead of indenting the block, you can use delimited blocks, if you l
# ...

# %%
len(uo.load())
# Out:
# 1

# %%
uo = UnstructuredMarkdownLoader(file_path="/content/markdown-sample.md",mode='elements')

# %%
len(uo.load())
# Out:
# 53

# %%
uo.load()[0].page_content
# Out:
# 'An h1 header'

# %%
uo.load()[45].page_content
# Out:
# 'Again, text is indented 4 spaces. (Put a blank line between each term/definition pair to spread things out more.)'

# %% [markdown]
# **# web based loader**

# %%
# web based loader

# %%
from langchain_community.document_loaders import WebBaseLoader,UnstructuredURLLoader
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
wo = WebBaseLoader(web_path="https://www.innomatics.in/")

# %%
data = wo.load() #documnet object

# %%
len(data)
# Out:
# 1

# %%
data[0].metadata
# Out:
# {'source': 'https://www.innomatics.in/',
#  'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India',
#  'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for Data Science & Digital Marketing. Collaboration with NASSCOM',
#  'language': 'en-US'}

# %%
print(data[0].page_content)
# Out:
#  Best Data Science & Big Data EdTech Company Hyderabad, India            Enquire Now:
# Hyderabad: üìû9951666670
# Dilsukhnagar: üìû9951666674
# Pune: üìû9951666671
# Bengaluru : üìû9951666672
# HomeCoursesData ScienceData Science CourseAdvanced Data AnalyticsOnline Data SciencePre-Placement ProgramFull Stack Web DevelopmentAdvance Generative AIProject Based LearningIT Scholars ProgramInternshipGenerative AI InternshipAbout usAbout usPlacementsPartner with usContact usBlogsReviewsGalleryTerms and PoliciesEventsCode4EdTech Hackathon Challenge by Innomatics Research LabsCrash Course on Data Analysis with Python5 Days Generative AI BootcampFree Online Data Science WebinarCampus AmbassadorFranchise
# ...

# %%
uo = UnstructuredURLLoader(urls=["https://www.innomatics.in/"],mode='single')

# %%
data= uo.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.innomatics.in/'}, page_content="Enquire Now:\n\nHyderabad: 📞9951666670\n\nDilsukhnagar: 📞9951666674\n\nPune: 📞9951666671\n\nBengaluru : 📞9951666672\n\n\n\nEnquire Now\n\nHYD: 9951666670\n\nPUNE: 9951666671\n\nDSNR: 9951666674\n\nBNGLR: 9951666672\n\nInnomatics\n\nMenuClose\n\nBranches across cities\n\nInnomatics - India’s Most Trusted EdTech Platform for Career Growth and Skill Development!\n\nInnomatics - India’s Most Trusted EdTech\n\nTimes Excellence award 2019-2020 for Best Data Science Institute\n\nBranches across cities\n\nInnomatics Research Labs\n\nInnomatics - India’s Most Trusted EdTech\n\nTimes of India Best Data Science Institute\n\nWe Don’t Just Train,\n\nWe Transform Careers\n\nInnomatics Research Labs is a pioneer in “Transforming Careers and Lives” of individuals in the Digital Space by catering advanced training on NASSCOM Future skills prime Certified Data Science, Python, Predictive Analytics Modeler, Machine Learning, Art
# ...

# %%
len(data)
# Out:
# 1

# %%
uo = UnstructuredURLLoader(urls=["https://www.innomatics.in/"],mode='elements')

# %%
data = uo.load()

# %%
len(data)
# Out:
# 215

# %%
data
# Out:
# [Document(metadata={'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'UncategorizedText'}, page_content='Enquire Now:'),
#  Document(metadata={'link_texts': ['Hyderabad: 📞9951666670'], 'link_urls': ['tel:9951666670'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'UncategorizedText'}, page_content='Hyderabad: 📞9951666670'),
#  Document(metadata={'link_texts': ['Dilsukhnagar: 📞9951666674'], 'link_urls': ['tel:9951666674'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'UncategorizedText'}, page_content='Dilsukhnagar: 📞9951666674'),
#  Document(metadata={'link_texts': ['Pune: 📞9951666671'], 'link_urls': ['tel:9951666671'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'UncategorizedText'}, page_content='Pune: 📞9951666671'),
# ...

# %%
data[0]
# Out:
# Document(metadata={'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'UncategorizedText'}, page_content='Enquire Now:')

# %%
data[0].metadata['category']
# Out:
# 'UncategorizedText'

# %%
s = set()
for y in data:
  s.add(y.metadata['category'])

# %%
s
# Out:
# {'Image', 'ListItem', 'NarrativeText', 'Title', 'UncategorizedText'}

# %%
s = set()
c = 0
for y in data:

    if y.metadata["category"] == "Table":
        print(c)

    s.add(y.metadata["category"])

    c += 1

# %%
s = set()
c = 0
for y in data:
  if y.metadata["category"] == "image":
    print(c)

  s.add(y.metadata['category'])
  c+=1

# %%
data[5]
# Out:
# Document(metadata={'image_url': 'http://innomatics.in/wp-content/uploads/2023/01/Innomatics-Logo1.png', 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.innomatics.in/', 'category': 'Image'}, page_content='')

# %% [markdown]
# **Youtube loader**

# %%
from langchain_community.document_loaders import YoutubeLoader

# %%
yo = YoutubeLoader.from_youtube_url("https://www.youtube.com/watch?v=NH-rzffOXFg")

# %%
# !pip install youtube-transcript-api

# %%
data = yo.load()[0].page_content

# %%
print(data)
# Out:
# It's been only a few months since I uncovered the biggest secret of my life. And yet, it's changed everything. Not just my world, but who I am. The head of the organization, the most feared, most hated man in Titan Academy is my father. Since their so-called rescue of the school, the organization has claimed to save Titan Academy from bankruptcy. That may be true, but at what cost? Expelling half the student body, forcing us into high stakes games, putting us through extreme punishments, recruiting spies, silencing them when they're no longer useful, turning this school into a machine fueled by power, profit, and fear. And at the center of it all, Mr. Alan, or as I know him, father. Ever since I found out, I've been living with a burden I never asked for. A secret I can't share with the very people I care about most. What would they think if they knew I shared blood with the monster behind it all? But what about my duties as a son? Do I keep hiding in denial? Or do I embrace who I am
# ...

# %% [markdown]
# **csvloader**

# %%
from langchain_community.document_loaders import CSVLoader,UnstructuredCSVLoader

# %%
csvo = CSVLoader(file_path="/content/tips.csv",csv_args={'delimiter':','})

# %%
len(csvo.load()) #each row as act lie a each document
# Out:
# 244

# %%
print(csvo.load()[0].page_content)
# Out:
# total_bill: 16.99
# tip: 1.01
# sex: Female
# smoker: No
# day: Sun
# time: Dinner
# size: 2

# %%
u = UnstructuredCSVLoader(file_path="/content/tips.csv",mode='single')

# %%
data = len(u.load())

# %%
data
# Out:
# 1

# %%
data = u.load()

# %%
data[0]
# Out:
# Document(metadata={'source': '/content/tips.csv'}, page_content='total_bill tip sex smoker day time size 16.99 1.01 Female No Sun Dinner 2 10.34 1.66 Male No Sun Dinner 3 21.01 3.5 Male No Sun Dinner 3 23.68 3.31 Male No Sun Dinner 2 24.59 3.61 Female No Sun Dinner 4 25.29 4.71 Male No Sun Dinner 4 8.77 2.0 Male No Sun Dinner 2 26.88 3.12 Male No Sun Dinner 4 15.04 1.96 Male No Sun Dinner 2 14.78 3.23 Male No Sun Dinner 2 10.27 1.71 Male No Sun Dinner 2 35.26 5.0 Female No Sun Dinner 4 15.42 1.57 Male No Sun Dinner 2 18.43 3.0 Male No Sun Dinner 4 14.83 3.02 Female No Sun Dinner 2 21.58 3.92 Male No Sun Dinner 2 10.33 1.67 Female No Sun Dinner 3 16.29 3.71 Male No Sun Dinner 3 16.97 3.5 Female No Sun Dinner 3 20.65 3.35 Male No Sat Dinner 3 17.92 4.08 Male No Sat Dinner 2 20.29 2.75 Female No Sat Dinner 2 15.77 2.23 Female No Sat Dinner 2 39.42 7.58 Male No Sat Dinner 4 19.82 3.18 Male No Sat Dinner 2 17.81 2.34 Male No Sat Dinner 4 13.37 2.0 Male No Sat Dinner 2 12.69 2.0 Male No Sa
# ...

# %%
u = UnstructuredCSVLoader(file_path="/content/tips.csv",mode='elements')

# %%
data = len(u.load())

# %%
data
# Out:
# 1

# %% [markdown]
# **json loader**

# %%
pip install jq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.8/773.8 kB 12.4 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import JSONLoader

# %%
jo = JSONLoader(file_path="/content/sample2.json",jq_schema=".",text_content=False)

# %%
data = jo.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/sample2.json', 'seq_num': 1}, page_content='{"firstName": "Joe", "lastName": "Jackson", "gender": "male", "age": 28, "address": {"streetAddress": "101", "city": "San Diego", "state": "CA"}, "phoneNumbers": [{"type": "home", "number": "7349282382"}]}')]

# %%
len(data)
# Out:
# 1

# %%
data[0].metadata
# Out:
# {'source': '/content/sample2.json', 'seq_num': 1}

# %%
data[0].page_content
# Out:
# '{"firstName": "Joe", "lastName": "Jackson", "gender": "male", "age": 28, "address": {"streetAddress": "101", "city": "San Diego", "state": "CA"}, "phoneNumbers": [{"type": "home", "number": "7349282382"}]}'

# %%
jo = JSONLoader(file_path="/content/sample2.json",jq_schema=".phoneNumbers[]",text_content=False)

# %%
data = jo.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/sample2.json', 'seq_num': 1}, page_content='{"type": "home", "number": "7349282382"}')]

# %%
data[0].page_content
# Out:
# '{"type": "home", "number": "7349282382"}'

# %%
jo = JSONLoader(file_path="/content/sample2.json",jq_schema=".phoneNumbers[].type",text_content=False)

# %%
data = jo.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/sample2.json', 'seq_num': 1}, page_content='home')]

# %%
data[0].page_content
# Out:
# 'home'

# %% [markdown]
# **pdf loader**

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader,UnstructuredPDFLoader

# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 17.8 MB/s eta 0:00:00
# ...

# %%
pdf1 = PyPDFLoader(file_path="/content/2601.15727v1.pdf")

# %%
d1 = pdf1.load()

# %%
len(d1)
# Out:
# 9

# %%
print(d1[0].page_content)
# Out:
# Towards Automated Kernel Generation in the Era of LLMs
# Yang Yu1 ,Peiyu Zang 1,2 ,Chi Hsu Tsai 1,3 ,Haiming Wu 1,4 ,Yixin Shen 1,5 ,
# Jialing Zhang1,6 ,Haoyu Wang 1,7 ,Zhiyou Xiao 1,3 ,Jingze Shi 8 ,Yuyu Luo 8 ,
# Wentao Zhang3 ,Chunlei Men 1 ,Guang Liu 1 andYonghua Lin 1
# 1Beijing Academy of Artificial Intelligence
# 2Beijing Normal University
# 3Peking University
# 4Beijing Institute of Technology
# 5Cornell University
# 6Beijing Jiaotong University
# 7Renmin University of China
# 8Hong Kong University of Science and Technology (Guangzhou)
# Abstract
# The performance of modern AI systems is funda-
# mentally constrained by the quality of their un-
# derlying kernels, which translate high-level algo-
# rithmic semantics into low-level hardware oper-
# ations. Achieving near-optimal kernels requires
# expert-level understanding of hardware architec-
# tures and programming models, making kernel en-
# gineering a critical but notoriously time-consuming
# ...

# %% [markdown]
# **PyMuPDFLoader**

# %%
pdf2 = PyMuPDFLoader(file_path="/content/2601.15727v1.pdf")

# %%
pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 25.9 MB/s eta 0:00:00
# ...

# %%
d2 = pdf2.load()

# %%
d2
# Out:
# [Document(metadata={'producer': 'pikepdf 8.15.1', 'creator': 'arXiv GenPDF (tex2pdf:57610bf)', 'creationdate': '', 'source': '/content/2601.15727v1.pdf', 'file_path': '/content/2601.15727v1.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': 'Towards Automated Kernel Generation in the Era of LLMs', 'author': 'Yang Yu; Peiyu Zang; Chi Hsu Tsai; Haiming Wu; Yixin Shen; Jialing Zhang; Haoyu Wang; Zhiyou Xiao; Jingze Shi; Yuyu Luo; Wentao Zhang; Chunlei Men; Guang Liu; Yonghua Lin', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Towards Automated Kernel Generation in the Era of LLMs\nYang Yu1 , Peiyu Zang1,2 , Chi Hsu Tsai1,3 , Haiming Wu1,4 , Yixin Shen1,5 ,\nJialing Zhang1,6 , Haoyu Wang1,7 , Zhiyou Xiao1,3 , Jingze Shi8 , Yuyu Luo8 ,\nWentao Zhang3 , Chunlei Men1 , Guang Liu1 and Yonghua Lin1\n1Beijing Academy of Artificial Intelligence\n2Beijing Normal University\n3Peking University\n4Beijing Institute of Te
# ...

# %%
pdf2 = PyMuPDFLoader(file_path="/content/2601.15727v1.pdf",extract_images=True)

# %%
d2 = pdf2.load()

# %%
d2[0].metadata
# Out:
# {'producer': 'pikepdf 8.15.1',
#  'creator': 'arXiv GenPDF (tex2pdf:57610bf)',
#  'creationdate': '',
#  'source': '/content/2601.15727v1.pdf',
#  'file_path': '/content/2601.15727v1.pdf',
#  'total_pages': 9,
#  'format': 'PDF 1.7',
#  'title': 'Towards Automated Kernel Generation in the Era of LLMs',
#  'author': 'Yang Yu; Peiyu Zang; Chi Hsu Tsai; Haiming Wu; Yixin Shen; Jialing Zhang; Haoyu Wang; Zhiyou Xiao; Jingze Shi; Yuyu Luo; Wentao Zhang; Chunlei Men; Guang Liu; Yonghua Lin',
#  'subject': '',
#  'keywords': '',
#  'moddate': '',
#  'trapped': '',
#  'modDate': '',
#  'creationDate': '',
#  'page': 0}

# %%
#strategy = auto|fast|hi_res|ocr_only

# %%
# !sudo apt-get install poppler-utils
# !sudo apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 2s (112 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
uo = UnstructuredPDFLoader(file_path="/content/2601.15727v1.pdf",mode="elements",strategy="hi_res",extract_images=True,extract_tables=True)

# %%
data = uo.load()

# %%
len(data)
# Out:
# 244

# %%
s = set()
c = 0
for y in data:

    if y.metadata["category"] == "Table":
        print(c)

    s.add(y.metadata["category"])

    c += 1
# Out:
# 105
# 154

# %%
data[105]
# Out:
# Document(metadata={'source': '/content/2601.15727v1.pdf', 'detection_class_prob': 0.901033341884613, 'is_extracted': 'true', 'coordinates': {'points': ((np.float64(207.0764617919922), np.float64(201.15472412109375)), (np.float64(207.0764617919922), np.float64(1634.7794189453125)), (np.float64(1521.9344482421875), np.float64(1634.7794189453125)), (np.float64(1521.9344482421875), np.float64(201.15472412109375))), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'links': [{'text': 'Lozhkov et al ., 2024', 'url': 'cite.lozhkov2024stackv2', 'start_index': 73}, {'text': 'HPC - AI Tech , 2024', 'url': 'cite.hpcinstruct2024', 'start_index': 117}, {'text': 'Paliskara and Saroufim , 2025', 'url': 'cite.kernelbook2025', 'start_index': 156}, {'text': 'Dao et al ., 2022', 'url': 'cite.dao2022flashattention', 'start_index': 132}, {'text': 'FlagOpen Team , 2023', 'url': 'cite.flagattention2023', 'start_index': 173}, {'text': 'AMD , 2024', 'url': 'cite.amd2024aotriton', 'start_i
# ...

# %%
s
# Out:
# {'FigureCaption',
#  'Formula',
#  'Header',
#  'Image',
#  'ListItem',
#  'NarrativeText',
#  'Table',
#  'Title',
#  'UncategorizedText'}

# %%
data[0].metadata
# Out:
# {'source': '/content/2601.15727v1.pdf',
#  'is_extracted': 'true',
#  'coordinates': {'points': ((np.float64(45.388888888888886),
#     np.float64(621.6666666666665)),
#    (np.float64(45.388888888888886), np.float64(649.4444444444443)),
#    (np.float64(100.94444444444446), np.float64(649.4444444444443)),
#    (np.float64(100.94444444444446), np.float64(621.6666666666665))),
#   'system': 'PixelSpace',
#   'layout_width': 1700,
#   'layout_height': 2200},
#  'last_modified': '2026-01-23T14:53:08',
#  'filetype': 'application/pdf',
#  'languages': ['eng'],
#  'page_number': 1,
#  'file_directory': '/content',
#  'filename': '2601.15727v1.pdf',
#  'category': 'UncategorizedText',
#  'element_id': 'ff856b37ffa4f8deb1b8414b806251dd'}

# %%
uo = UnstructuredPDFLoader(file_path="/content/2601.15727v1.pdf",mode="elements",strategy="hi_res",extract_images_in_pdf=True,extract_tables_in_pdf=True)

# %%
data =uo.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/2601.15727v1.pdf', 'is_extracted': 'true', 'coordinates': {'points': ((np.float64(45.388888888888886), np.float64(621.6666666666665)), (np.float64(45.388888888888886), np.float64(649.4444444444443)), (np.float64(100.94444444444446), np.float64(649.4444444444443)), (np.float64(100.94444444444446), np.float64(621.6666666666665))), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'last_modified': '2026-01-23T14:53:08', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'file_directory': '/content', 'filename': '2601.15727v1.pdf', 'category': 'UncategorizedText', 'element_id': 'ff856b37ffa4f8deb1b8414b806251dd'}, page_content='6'),
# ...

# %%
from langchain_community.document_loaders import UnstructuredImageLoader

# %%
uo = UnstructuredImageLoader(file_path="/content/How-to-Make-Text-Stand-Out-And-More-Readable.webp")

# %%
data = uo.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/How-to-Make-Text-Stand-Out-And-More-Readable.webp'}, page_content='“« MAKE TEXT\n\nSTAND OUT FROM\n\n7” <<) 7 A\n\n), +9 f)\n\nBACKGROUNDS')]

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader

# %%
uo = UnstructuredPowerPointLoader(file_path="/content/Agentic_AI_Presentation.pptx",mode="paged")

# %%
data = uo.load()
# Out:
# WARNING:/usr/local/lib/python3.12/dist-packages/langchain_community/document_loaders/unstructured.py:`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking

# %%
data
# Out:
# [Document(metadata={'source': '/content/Agentic_AI_Presentation.pptx', 'category_depth': 1, 'file_directory': '/content', 'filename': 'Agentic_AI_Presentation.pptx', 'last_modified': '2026-01-23T17:03:10', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': 'dbfc305dbe0241879c6e9d46f21737cf'}, page_content='Agentic AI\n\nA Simple Overview\n\n\n\n'),
# ...

# %%
len(data)
# Out:
# 4

# %%
print(data[0].page_content)
# Out:
# Agentic AI
#
# A Simple Overview

# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

# %%
uo = UnstructuredWordDocumentLoader(file_path="/content/List Comprehensions.docx",mode="paged")

# %%
data = uo.load()
# Out:
# WARNING:/usr/local/lib/python3.12/dist-packages/langchain_community/document_loaders/unstructured.py:`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking

# %%
data
# Out:
# [Document(metadata={'source': '/content/List Comprehensions.docx', 'category_depth': 0, 'file_directory': '/content', 'filename': 'List Comprehensions.docx', 'last_modified': '2026-01-23T17:12:02', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'emphasized_text_contents': ['Given a string', 'text = "list comprehension is powerful"', ', use list comprehension to create a list of characters where vowels are replaced by', "'*'", '.'], 'emphasized_text_tags': ['b', 'b', 'b', 'b', 'b'], 'parent_id': '7818dddaa33470618e6325967e818e30'}, page_content='List  Comprehensions\n\nCreate a list of squares from 1 to 10 using list comprehension.\n Expected Output: [1, 4, 9, ..., 100]\n\nFrom a list of numbers, create a new list containing only even numbers using list comprehension.\n nums = [1, 2, 3, 4, 5, 6] → [2, 4, 6]\n\nConvert all words in a list to uppercase using list comprehension.\n words = [\'hello\', \'world\'] → [\'HELLO\', \
# ...

# %%
len(data)
# Out:
# 11
